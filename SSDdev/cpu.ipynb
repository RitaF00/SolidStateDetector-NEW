# %%
cd("/home/ritaferi/Phd/SSDdev")
using Pkg
Pkg.activate(".")
Pkg.instantiate()

using SolidStateDetectors
# Out:
#   Activating project at `~/Phd/SSDdev`
# Precompiling packages...
#   11993.3 ms  ✓ SolidStateDetectors
#   1 dependency successfully precompiled in 13 seconds. 323 already precompiled.

# %%
Base.Threads.nthreads()
# Out:
# 1
