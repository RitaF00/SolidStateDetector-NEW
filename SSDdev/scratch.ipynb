# %%
using Pkg


using SolidStateDetectors
using Unitful
using Plots
using LegendHDF5IO

# %%
save_sim_path = "saved_simulation/sim.h5"
sim = ssd_read(save_sim_path, Simulation)
# Out:
# Simulation{Float32, Cylindrical} - Coordinate system: Cylindrical
#   Environment Material: Vacuum
#   Detector: Public Inverted Coax
#   Electric potential: (578, 1, 1096)
#   Charge density: (578, 1, 1096)
#   Impurity scale: (578, 1, 1096)
#   Fix Charge density: (578, 1, 1096)
#   Dielectric distribution: (579, 2, 1097)
#   Point types: (578, 1, 1096)
#   Electric field: missing
#   Weighting potentials:
#     Contact 1: missing
#     Contact 2: missing

# %%
sim.world.intervals[3].right/sim.world.intervals[1].right
# Out:
# 2.2500002f0

# %%
Δr = sim.world.intervals[1].right/sim.world.intervals[1].right * 1u"mm"
# Out:
# 1.0f0 mm

# %%
sim.world.intervals[1].right *1000u"mm" /4
# Out:
# 10.0f0 mm

# %%
sim.world.intervals[1].right
# Out:
# 0.04f0
