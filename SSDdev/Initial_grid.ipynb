# %%
cd("/home/ritaferi/Phd/SSDdev")
using Pkg
Pkg.activate(".")


using SolidStateDetectors
using Unitful
using Plots
using Interpolations
using LegendHDF5IO
using IntervalSets
# Out:
#   Activating project at `~/Phd/SSDdev`

# %%
save_sim_path = "saved_simulation/sim_ILM.h5"

sim = ssd_read(save_sim_path, Simulation)
# Out:
# Simulation{Float32, Cylindrical} - Coordinate system: Cylindrical
#   Environment Material: Vacuum
#   Detector: Public Inverted Coax Inactive
#   Electric potential: (312, 1, 396)
#   Charge density: (312, 1, 396)
#   Impurity scale: (312, 1, 396)
#   Fix Charge density: (312, 1, 396)
#   Dielectric distribution: (313, 2, 397)
#   Point types: (312, 1, 396)
#   Electric field: missing
#   Weighting potentials:
#     Contact 1: missing
#     Contact 2: missing

# %%
 world_Δs = width.(sim.world.intervals)
 world_Δr, world_Δφ, world_Δz = world_Δs
# Out:
# (0.04f0, 0.0f0, 0.1f0)

# %%
min_ΔL = ( min( world_Δr, world_Δz) / 2 ) * u"mm"
# Out:
# 0.02f0 mm

# %%
max_tick_distance = (0.1u"mm", 1u"rad", 5u"mm")
# Out:
# (0.1 mm, 1 rad, 5 mm)

# %%
smaller_max_tick_distance = minimum((max_tick_distance[1],max_tick_distance[3]))
# Out:
# 0.1 mm

# %%
min_ΔL = 5u"mm"
# Out:
# 5 mm

# %%
if max_tick_distance isa Tuple
                    println("max_tick_distance is an array")
                    smaller_max_tick_distance = minimum((max_tick_distance[1], max_tick_distance[3]))
                else
                    # scalar
                    smaller_max_tick_distance = max_tick_distance
                end
# Out:
# max_tick_distance is an array
# 0.1 mm

# %%
if max_tick_distance isa Array
    println("miao")
end

# %%
!ismissing(max_tick_distance)
# Out:
# true

# %%
if smaller_max_tick_distance < min_ΔL
    println("miao")
end
# Out:
# miao

# %%
sim = Simulation(SSD_examples[:InvertedCoax])
plot(sim.detector, size = (400, 400))
sim.detector = SolidStateDetector(sim.detector, contact_id=2, contact_potential=500u"V");

# %%
initial_grid = Grid(sim,
                    for_weighting_potential=false,  # false = electric potential
                    max_tick_distance=5u"mm")
# Out:
# Entro in Grid
# ...

# %%
sim.detector
# Out:
# ________Public Inverted Coax________
#
# ---General Properties---
# - Precision type: Float32
#
# 	_____Semiconductor_____
#
# Semiconductor{Float32} - High Purity Germanium
#
# # Contacts: 2
# Contact 1 - 0.0 V - High Purity Germanium
# Contact 2 - 500.0 V - High Purity Germanium
#
# # Passives: 1
# Passive Passivation Layer - id -1 - NaN V
